# %%
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf().setMaster("local").setAppName("word_count")

# %%
sc = SparkContext().getOrCreate(conf=conf)

# %%
rdd1 = sc.textFile("D:\\BigData\\Week9- Apache Spark\\search_data.txt")

# %%
rdd2 = rdd1.flatMap(lambda x: x.split(" "))

# %%
rdd3 = rdd2.map(lambda x: (str(x),1))

# %%
rdd4 = rdd3.reduceByKey(lambda x,y: x+y)

# %%
rdd4.collect()
# Out:
# [('best', 29),
#  ('hadoop', 96),
#  ('training', 111),
#  ('intellepaat', 1),
#  ('microsoft', 3),
#  ('in', 169),
#  ('online', 58),
#  ('preparation', 1),
#  ('mining', 2),
#  ('programs', 4),
#  ('module', 1),
#  ('1', 5),
#  ('PYTHON', 2),
#  ('delhi', 8),
#  ('HADOOP', 4),
#  ('analytics', 35),
#  ('professional', 2),
#  ('institute', 19),
#  ('good', 2),
#  ('questions', 3),
#  ('contents', 1),
#  ('b', 3),
#  ('sc', 1),
#  ('third', 1),
#  ('class', 6),
#  ('of', 27),
#  ('master', 4),
#  ('basics', 2),
#  ('days', 2),
#  ('is', 12),
#  ('starting', 1),
#  ('5www', 1),
#  ('im', 1),
#  ('cloudx', 2),
#  ('lab', 4),
#  ('credentials', 1),
#  ('coarse', 1),
#  ('ecosystems', 1),
#  ('intoduction', 1),
#  ('flair', 4),
#  ('www', 4),
#  ('intellipaat', 10),
#  ('pass', 2),
#  ('do', 2),
#  ('hacking', 1),
#  ('congitive', 1),
#  ('sheet', 1),
#  ('groups', 1),
#  ('analyst', 11),
#  ('python', 8),
#  ('bigdata', 19),
#  ('linkedin', 1),
#  ('centres', 2),
#  ('project', 3),
#  ('title', 1),
#  ('engineering', 9),
#  ('coaching', 6),
#  ('engineer', 9),
#  ('eligibility', 3),
#  ('scala', 10),
#  ('chahie', 1),
#  ('month', 1),
#  ('2020', 5),
#  ('20', 2),
#  ('placement', 11),
#  ('full', 4),
#  ('stack', 1),
#  ('thane', 1),
#  ('congnitive', 1),
#  ('ibm', 4),
#  ('udemy', 2),
#  ('diploma', 4),
#  ('definitive', 1),
#  ('guide', 2),
#  ('c++', 1),
#  ('banking', 1),
#  ('analytical', 1),
#  ('startups', 1),
#  ('hive', 2),
#  ('i', 2),
#  ('am', 1),
#  ('willing', 1),
#  ('career', 4),
#  ('projects', 5),
#  ('vourse', 1),
#  ('fee', 8),
#  ('paid', 1),
#  ('ameerpet', 6),
#  ('just', 1),
#  ('below', 1),
#  ('velachery', 1),
#  ('bigdaa', 1),
#  ('seema', 1),
#  ('subhashini', 1),
#  ('chellappan', 1),
#  ('infosys', 1),
#  ('limited', 2),
#  ('publication', 1),
#  ('wiley', 1),
#  ('private', 1),
#  ('1st', 1),
#  ('edition', 1),
#  ('hiw', 1),
#  ('orovide', 1),
#  ('college', 3),
#  ('contentsbto', 1),
#  ('ata', 1),
#  ('ayllabus', 1),
#  ('import', 1),
#  ('database', 1),
#  ('as', 1),
#  ('files', 1),
#  ('hdfs', 1),
#  ('generate', 1),
#  ('java', 4),
#  ('interact', 1),
#  ('step', 2),
#  ('roorkee', 3),
#  ('learning', 12),
#  ('trivandrum', 1),
#  ('school', 2),
#  ('nural', 1),
#  ('network', 1),
#  ('store', 1),
#  ('very', 1),
#  ('large', 3),
#  ('amounts', 1),
#  ('lms', 1),
#  ('trending', 1),
#  ('hat', 1),
#  ('fees', 10),
#  ('institutes', 12),
#  ('4', 2),
#  ('weeks', 1),
#  ('april', 2),
#  ('may', 1),
#  ('21', 1),
#  ('azure', 1),
#  ('feedback', 1),
#  ('an', 3),
#  ('ipc', 2),
#  ('org', 1),
#  ('standbyexception', 1),
#  ('mind', 1),
#  ('jigsaw', 3),
#  ('image', 2),
#  ('lower', 1),
#  ('driver', 1),
#  ('continuous', 1),
#  ('pay', 1),
#  ('after', 1),
#  ('using', 3),
#  ('impala', 1),
#  ('world', 1),
#  ('tools', 1),
#  ('google', 2),
#  ('bihar', 3),
#  ('physics', 1),
#  ('12', 2),
#  ('zaloni', 1),
#  ('docker', 1),
#  ('storage', 1),
#  ('scd', 1),
#  ('material', 1),
#  ('details', 3),
#  ('npntraining', 1),
#  ('deta', 1),
#  ('anyaless', 1),
#  ('algorithm', 1),
#  ('live', 3),
#  ('several', 1),
#  ('_', 2),
#  ('rapid', 1),
#  ('books', 1),
#  ('community', 1),
#  ('dlehi', 1),
#  ('center', 3),
#  ('europe', 1),
#  ('ivyproschool', 1),
#  ('overview', 2),
#  ('name', 1),
#  ('tamil', 2),
#  ('pipeline', 1),
#  ('concepts', 1),
#  ('related', 1),
#  ('latest', 2),
#  ('similar', 1),
#  ('assignments', 1),
#  ('value', 1),
#  ('coimbatore', 1),
#  ('solution', 2),
#  ('university', 3),
#  ('job', 3),
#  ('power', 1),
#  ('minutes', 1),
#  ('topic', 1),
#  ('speech', 1),
#  ('vtu', 1),
#  ('following', 2),
#  ('science', 1),
#  ('sum', 1),
#  ('week', 2),
#  ('trainjng', 1),
#  ('benefits', 1),
#  ('site', 1),
#  ('regular', 1),
#  ('100', 1),
#  ('django', 1),
#  ('go', 1),
#  ('updates', 1),
#  ('opportunities', 2),
#  ('end', 2),
#  ('scratch', 3),
#  ('line', 1),
#  ('calculator', 1),
#  ('where', 2),
#  ('unacademy', 1),
#  ('offered', 1),
#  ('engg', 1),
#  ('australia', 1),
#  ('starter', 1),
#  ('kit', 1),
#  ('geoinsyssoft', 1),
#  ('new', 1),
#  ('zealand', 1),
#  ('*', 1),
#  ('near', 6),
#  ('provision', 1),
#  ('datafalir', 1),
#  ('cca', 1),
#  ('175', 1),
#  ('trainer', 2),
#  ('acknowledge', 1),
#  ('there', 2),
#  ('helping', 1),
#  ('multiple', 1),
#  ('lakes', 2),
#  ('bits', 3),
#  ('pilani', 3),
#  ('noida', 1),
#  ('draw', 1),
#  ('framework', 1),
#  ('analytic', 1),
#  ('hdpcd', 1),
#  ('aws', 1),
#  ('storahe', 1),
#  ('broadway', 1),
#  ('cochig', 1),
#  ('javatpoint', 1),
#  ('classroom', 1),
#  ('intellepat', 1),
#  ('sathish', 1),
#  ('providers', 2),
#  ('gemology', 1),
#  ('we', 1),
#  ('start', 1),
#  ('rahul', 1),
#  ('subject', 1),
#  ('would', 1),
#  ('help', 1),
#  ('mumbai', 1),
#  ('analytixlabs', 1),
#  ('fundamentals', 1),
#  ('techetraining', 1),
#  ('TRAINING', 3),
#  ('co', 1),
#  ('cse', 1),
#  ('STUDENT', 1),
#  ('technology', 3),
#  ('ca', 1),
#  ('coursedata', 1),
#  ('itversity', 1),
#  ('mongo', 1),
#  ('MICROSOFT', 1),
#  ('indore', 1),
#  ('cassandra', 1),
#  ('entrycomputer', 1),
#  ('rajouri', 1),
#  ('garden', 1),
#  ('ARCHITECTURE', 1),
#  ('kr', 1),
#  ('puram', 1),
#  ('loading', 1),
#  ('oracle', 1),
#  ('2.4', 1),
#  ('peer', 1),
#  ('https', 1),
#  ('numpy', 1),
#  ('cloud', 1),
#  ('action', 1),
#  ('vancouver', 1),
#  ('distance', 2),
#  ('intelipatt', 1),
#  ('trainin', 1),
#  ('presto', 1),
#  ('freshers', 1),
#  ('tranning', 1),
#  ('UDACITY', 1),
#  ('players', 1),
#  ('laptop', 1),
#  ('tutorials', 1),
#  ('offering', 1),
#  ('select', 1),
#  ('expert', 1),
#  ('SCALA', 1),
#  ('beginner', 1),
#  ('PGP', 1),
#  ('last', 2),
#  ('year', 1),
#  ('question', 1),
#  ('charging', 1),
#  ('rcm', 1),
#  ('10', 1),
#  ('banglore', 1),
#  ('bid', 1),
#  ('use', 1),
#  ('search', 1),
#  ('used', 1),
#  ('horizontal', 1),
#  ('scalability', 1),
#  ('true', 1),
#  ('bigdataphysicsclasses', 1),
#  ('nlp', 1),
#  ('task', 1),
#  ('artificial', 1),
#  ('when', 2),
#  ('steps', 1),
#  ('big', 279),
#  ('data', 354),
#  ('spark', 42),
#  ('kelly', 2),
#  ('technologies', 3),
#  ('courses', 53),
#  ('cloudera', 6),
#  ('partner', 1),
#  ('india', 16),
#  ('certification', 26),
#  ('BIG', 6),
#  ('DATA', 7),
#  ('COURSE', 1),
#  ('IN', 2),
#  ('DELHI', 1),
#  ('acadgild', 3),
#  ('coursera', 9),
#  ('chennai', 20),
#  ('developer', 4),
#  ('hyderabad', 33),
#  ('computer', 1),
#  ('course', 104),
#  ('report', 1),
#  ('bangalore', 38),
#  ('certified', 3),
#  ('apache', 15),
#  ('classes', 11),
#  ('interview', 2),
#  ('tech', 1),
#  ('comp', 1),
#  ('for', 30),
#  ('all', 1),
#  ('the', 12),
#  ('5', 1),
#  ('session', 1),
#  ('gs', 1),
#  ('n', 1),
#  ('qjavq5catum', 1),
#  ('edureka', 11),
#  ('marathahalli', 3),
#  ('list', 2),
#  ('prwatech', 2),
#  ('beginners', 6),
#  ('com', 6),
#  ('mapr', 1),
#  ('academy', 5),
#  ('who', 1),
#  ('can', 2),
#  ('tamilnadu', 1),
#  ('bangkok', 1),
#  ('cheat', 1),
#  ('cloudxlab', 5),
#  ('review', 4),
#  ('study', 5),
#  ('lucknow', 1),
#  ('reviews', 6),
#  ('specialization', 2),
#  ('trainers', 1),
#  ('qualification', 1),
#  ('to', 21),
#  ('learn', 15),
#  ('haarop', 1),
#  ('software', 3),
#  ('content', 4),
#  ('cdac', 1),
#  ('duration', 1),
#  ('inceptez', 2),
#  ('blog', 1),
#  ('and', 22),
#  ('kya', 1),
#  ('msc', 3),
#  ('ke', 2),
#  ('liye', 2),
#  ('cipet', 1),
#  ('3', 3),
#  ('top', 8),
#  ('with', 21),
#  ('what', 2),
#  ('analysis', 5),
#  ('complete', 3),
#  ('tutorial', 15),
#  ('kundalahalli', 1),
#  ('labs', 1),
#  ('pg', 7),
#  ('crunching', 1),
#  ('claases', 1),
#  ('sample', 2),
#  ('finance', 1),
#  ('from', 8),
#  ('nsdc', 1),
#  ('simplilearn', 6),
#  ('faculty', 1),
#  ('leanr', 1),
#  ('teachers', 1),
#  ('masters', 4),
#  ('programme', 1),
#  ('not', 2),
#  ('it', 3),
#  ('backgroud', 1),
#  ('kolkata', 3),
#  ('real', 2),
#  ('life', 1),
#  ('sla', 1),
#  ('under', 1),
#  ('3000', 1),
#  ('cost', 6),
#  ('iit', 10),
#  ('time', 3),
#  ('inspecs', 1),
#  ('acharya', 1),
#  ('2', 4),
#  ('udacity', 1),
#  ('program', 7),
#  ('jobs', 2),
#  ('dataflair', 6),
#  ('catalog', 1),
#  ('bigdatauniversity', 1),
#  ('international', 3),
#  ('acadamy', 1),
#  ('thiruvanthapuram', 1),
#  ('you', 1),
#  ('need', 1),
#  ('a', 5),
#  ('portion', 1),
#  ('relational', 1),
#  ('every', 1),
#  ('day', 1),
#  ('your', 1),
#  ('emcdsa', 1),
#  ('hands', 1),
#  ('on', 7),
#  ('sql', 4),
#  ('upgrad', 1),
#  ('by', 9),
#  ('great', 3),
#  ('dataframe', 1),
#  ('foundation', 1),
#  ('computing', 1),
#  ('digital', 2),
#  ('marketing', 2),
#  ('cluster', 2),
#  ('setup', 1),
#  ('ivy', 2),
#  ('pro', 2),
#  ('conitive', 1),
#  ('certificate', 2),
#  ('red', 1),
#  ('cognativeclasses', 1),
#  ('colleges', 4),
#  ('which', 8),
#  ('offer', 1),
#  ('pune', 8),
#  ('kafka', 1),
#  ('jaipur', 2),
#  ('13', 1),
#  ('datatutorial', 1),
#  ('lake', 2),
#  ('attending', 1),
#  ('workshop', 1),
#  ('rg', 1),
#  ('remoteexception', 1),
#  ('architect', 7),
#  ('skills', 1),
#  ('types', 2),
#  ('dataset', 1),
#  ('code', 2),
#  ('yraining', 1),
#  ('show', 1),
#  ('light', 1),
#  ('anlyst', 1),
#  ('banks', 1),
#  ('be', 1),
#  ('understanding', 1),
#  ('text', 1),
#  ('hindi', 2),
#  ('sharif', 3),
#  ('example', 2),
#  ('visualizing', 1),
#  ('kubernetes', 2),
#  ('sqoop', 1),
#  ('nit', 1),
#  ('rourkela', 1),
#  ('taming', 1),
#  ('eureka', 1),
#  ('btm', 3),
#  ('layout', 3),
#  ('pdg', 1),
#  ('excelr', 1),
#  ('hortonworks', 1),
#  ('kolhapur', 1),
#  ('sessions', 1),
#  ('denotes', 1),
#  ('volume', 2),
#  ('kinds', 1),
#  ('that', 1),
#  ('changes', 1),
#  ('ina', 1),
#  ('acadglid', 1),
#  ('cognative', 1),
#  ('uk', 2),
#  ('intro', 1),
#  ('data101', 1),
#  ('websie', 1),
#  ('one', 1),
#  ('drivers', 1),
#  ('dat', 1),
#  ('queries', 2),
#  ('helper', 1),
#  ('necessary', 1),
#  ('has', 1),
#  ('places', 1),
#  ('case', 1),
#  ('github', 1),
#  ('guarantee', 2),
#  ('bi', 1),
#  ('centre', 2),
#  ('english', 1),
#  ('e', 2),
#  ('part', 1),
#  ("v's", 1),
#  ('per', 1),
#  ('bharti', 1),
#  ('pgp', 1),
#  ('required', 2),
#  ('rdd', 1),
#  ('access', 1),
#  ('gcp', 1),
#  ('information', 1),
#  ('about', 1),
#  ('placements', 1),
#  ('intership', 1),
#  ('hydrabad', 1),
#  ('motivation', 1),
#  ('behind', 1),
#  ('edvancer', 1),
#  ('bharathiar', 1),
#  ('mba', 1),
#  ('students', 1),
#  ('jnu', 1),
#  ('m', 1),
#  ('conduct', 1),
#  ('edupristine', 1),
#  ('applications', 1),
#  ('omr', 1),
#  ('discount', 1),
#  ('linux', 1),
#  ('me', 5),
#  ('mapreduce', 1),
#  ('application', 1),
#  ('classpath', 1),
#  ('structure', 1),
#  ('greatlearing', 1),
#  ('paras', 1),
#  ('mitx', 1),
#  ('uppal', 1),
#  ('comment', 1),
#  ('nmims', 1),
#  ('firms', 1),
#  ('universities', 2),
#  ('any', 1),
#  ('choice', 1),
#  ('quesy', 1),
#  ('1ywar', 1),
#  ('south', 1),
#  ('cca175', 1),
#  ('could', 1),
#  ('testers', 1),
#  ('subjects', 1),
#  ('iguru', 1),
#  ('app', 2),
#  ('costs', 1),
#  ('ignite', 1),
#  ('topics', 1),
#  ('yellanki', 1),
#  ('learnbay', 1),
#  ('kharadi', 1),
#  ('email', 1),
#  ('khati', 1),
#  ('SIMPLILEARN', 1),
#  ('strategy', 1),
#  ('greatlearning', 1),
#  ('BIGDATA', 1),
#  ('affiliations', 1),
#  ('keyskills', 1),
#  ('ofhadoop', 1),
#  ('adminstartor', 1),
#  ('technogeeks', 1),
#  ('radicaltechnologies', 1),
#  ('most', 1),
#  ('institution', 1),
#  ('cv', 1),
#  ('architecture', 1),
#  ('patna', 1),
#  ('amity', 1),
#  ('answer', 1),
#  ('costing', 1),
#  ('db', 1),
#  ('scienctist', 1),
#  ('axtria', 1),
#  ('fre', 1),
#  ('degree', 1),
#  ('important', 1),
#  ('101', 1),
#  ('intellipat', 1),
#  ('intelipat', 1),
#  ('paper', 2),
#  ('BANGALORE', 2),
#  ('edulab', 1),
#  ('graded', 1),
#  ('assignment', 1),
#  ('solutions', 1),
#  ('weekend', 1),
#  ('tutor', 1),
#  ('blogs', 1),
#  ('processing', 1),
#  ('scipy', 1),
#  ('qlikview', 1),
#  ('utilized', 1),
#  ('today', 1),
#  ('pgdm', 1),
#  ('birla', 1),
#  ('trining', 1),
#  ('education', 1),
#  ('largest', 1),
#  ('genomics', 1),
#  ('syllabus', 2),
#  ('prerequisites', 1),
#  ('databricks', 2),
#  ('1000', 1),
#  ('dollars', 1),
#  ('quora', 1),
#  ('advance', 1),
#  ('minimum', 1),
#  ('qualifications', 1),
#  ('section', 1),
#  ('kphb', 1),
#  ('web', 1),
#  ('mca', 1),
#  ('quiz', 1),
#  ('collect', 1),
#  ('location', 1),
#  ('supporting', 1),
#  ('or', 1),
#  ('false', 1),
#  ('assessment', 1),
#  ('intelligence', 1),
#  ('date', 1),
#  ('vidya', 1),
#  ('learnathone', 1)]
